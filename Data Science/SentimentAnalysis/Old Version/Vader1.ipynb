# %%
import pandas as pd
import nltk

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer


analyzer = SentimentIntensityAnalyzer()
sentence = "Pepega" 
vs = analyzer.polarity_scores(sentence)

# %%
print("{:-<65} {}".format(sentence, str(vs)))
# Out:
# Pepega----------------------------------------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
pwd
# Out:
# 'C:\\Users\\flipi\\PhytonExercises\\Github\\Project'

# %%
greek_ds = pd.read_csv('ChatLogs/chatgreekgodx091421Clean.csv')

# %%
greek_ds.head()
# Out:
#                   Date     Channel         Username  \
# 0  2021-09-14 17:51:09  greekgodx         mustfax19
# 1  2021-09-14 17:51:09  greekgodx          bangkeys
# 2  2021-09-14 17:51:09  greekgodx   exiledxinsanity
# 3  2021-09-14 17:51:10  greekgodx          bilaal44
# 4  2021-09-14 17:51:10  greekgodx            leeqox
#
#                           Message  Tag_owner Cleanest_message
# 0                          Pepega          0           Pepega
# 1              Irl stream snipers          0    stream sniper
# 2             v tec kicked in Pog          0       i tec kick
# 3                          GOBLIN          0           goblin
# 4  Alarm turn up the volume Alarm          0       alarm turn

# %%
new_emotes = {
    'omegalul': -2,
    'lilw': 0,
    'monkaw': -3.0,
    'waytoodank': 0,
    'ez': 2.0,
    'clap' : 3.0,
    'lul' : 0,
    'booba' : 1.0,
    'pepega' : -3.0,
    'feelsgoodman' : 3.0,
    'wutface' : -3.0,
    'sadge' : -4.0,
    'kreygasm' : 3.0,
    'kappa' : 0,
    'peeposad' : -4.0,
    'pogu' : 4.0,
    'truening' : 0,
    'monkas' : -2
}

# %%
analyzer.lexicon.update(new_emotes)

# %%
analyzer.lexicon['Pepega']
# Out:
# -3.0

# %%
analyzer.polarity_scores('Pepega')['compound']
# Out:
# -0.6124

# %%
greek_ds['scores'] = greek_ds['Cleanest_message'].apply(lambda clean_message:analyzer.polarity_scores(clean_message))

# %%
greek_ds.head(25)
# Out:
#                    Date     Channel          Username  \
# 0   2021-09-14 17:51:09  greekgodx          mustfax19
# 1   2021-09-14 17:51:09  greekgodx           bangkeys
# 2   2021-09-14 17:51:09  greekgodx    exiledxinsanity
# 3   2021-09-14 17:51:10  greekgodx           bilaal44
# 4   2021-09-14 17:51:10  greekgodx             leeqox
# 5   2021-09-14 17:51:10  greekgodx            adamev1
# 6   2021-09-14 17:51:11  greekgodx             proxe0
# 7   2021-09-14 17:51:11  greekgodx            paxt___
# 8   2021-09-14 17:51:12  greekgodx           spr1nt3r
# 9   2021-09-14 17:51:12  greekgodx       ahmet_charts
# 10  2021-09-14 17:51:12  greekgodx   badmindsetabuser
# 11  2021-09-14 17:51:13  greekgodx           fartecho
# 12  2021-09-14 17:51:14  greekgodx      futsunoningen
# 13  2021-09-14 17:51:14  greekgodx           mrdude90
# 14  2021-09-14 17:51:15  greekgodx            dihomer
# 15  2021-09-14 17:51:15  greekgodx           fluxenis
# ...

# %%
df['compound'] = df['scores'].apply(lambda d:d['compound'])
